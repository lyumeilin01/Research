# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from miditok import MIDILike, TokenizerConfig
from miditoolkit import MidiFile
from pathlib import Path
import numpy as np
from IPython.display import Audio
import matplotlib.pyplot as plt
import pretty_midi

# %%
# Our parameters
TOKENIZER_PARAMS = {
    "pitch_range": (21, 109),
    "num_velocities": 1,
    "special_tokens": ["PAD", "BOS", "EOS"],
    "use_chords": False,
    "use_rests": False,
    "use_tempos": True,
    "use_time_signatures": False,
    "use_programs": False,
    "num_tempos":1,
    "tempo_range":(120,120)
}
config = TokenizerConfig(**TOKENIZER_PARAMS)
tokenizer = MIDILike(config)

# %%
tokens = tokenizer(Path("../../data/melody/ashover11.mid"))

# %%
tokens[0].tokens[:10]  # Show the first 10 tokens
# Out:
# ['Tempo_120.0',
#  'TimeShift_2.4.8',
#  'NoteOn_76',
#  'Velocity_127',
#  'TimeShift_0.4.8',
#  'NoteOff_76',
#  'NoteOn_74',
#  'Velocity_127',
#  'TimeShift_0.4.8',
#  'NoteOff_74']

# %%
midi = pretty_midi.PrettyMIDI("../../data/melody/ashover11.mid")

# %%
tempo_changes_times, tempo_changes_bpm = midi.get_tempo_changes()
print(f"Tempo change times (seconds): {tempo_changes_times}")
print(f"Tempo change BPMs: {tempo_changes_bpm}")
# Out:
# Tempo change times (seconds): [0.]
# Tempo change BPMs: [120.]

# %%
for i, instrument in enumerate(midi.instruments):
    print(f"\n--- Notes for Instrument #{i}: {instrument.name} ---")
    if instrument.is_drum:
        print("  (This is a drum track, pitch numbers map to drum sounds)")

    for note in instrument.notes:
        # Note Attributes:
        # - note.start: Start time of the note in seconds
        # - note.end: End time of the note in seconds
        # - note.pitch: MIDI note number (0-127). 60 is Middle C.
        # - note.velocity: MIDI velocity (0-127), how "hard" the note was played.
        print(f"  Pitch: {note.pitch}, Start: {note.start}s, End: {note.end}s, Duration: {note.end - note.start}s, Velocity: {note.velocity}")

        # You can also convert MIDI pitch to a note name (requires `pretty_midi.utilities`)
        note_name = pretty_midi.note_number_to_name(note.pitch)
        print(f"    Note Name: {note_name}")
# Out:
# --- Notes for Instrument #0:  ---
#   Pitch: 76, Start: 1.25s, End: 1.5s, Duration: 0.25s, Velocity: 90
#     Note Name: E5
#   Pitch: 74, Start: 1.5s, End: 1.75s, Duration: 0.25s, Velocity: 90
#     Note Name: D5
#   Pitch: 73, Start: 1.75s, End: 2.0s, Duration: 0.25s, Velocity: 90
#     Note Name: C#5
#   Pitch: 74, Start: 2.0s, End: 2.25s, Duration: 0.25s, Velocity: 90
#     Note Name: D5
#   Pitch: 66, Start: 2.25s, End: 2.5s, Duration: 0.25s, Velocity: 90
#     Note Name: F#4
#   Pitch: 69, Start: 2.5s, End: 2.75s, Duration: 0.25s, Velocity: 90
#     Note Name: A4
#   Pitch: 71, Start: 2.75s, End: 3.0s, Duration: 0.25s, Velocity: 90
#     Note Name: B4
#   Pitch: 74, Start: 3.0s, End: 3.25s, Duration: 0.25s, Velocity: 90
#     Note Name: D5
#   Pitch: 73, Start: 3.25s, End: 3.5s, Duration: 0.25s, Velocity: 90
#     Note Name: C#5
#   Pitch: 74, Start: 3.5s, End: 3.75s, Duration: 0.25s, Velocity: 90
#     Note Name: D5
#   Pitch: 71, Start: 3.75s, End: 4.0s, Duration: 0.25s, Velocity: 90
#     Note Name: B4
#   Pitch: 69, Start: 4.0s, End: 4.25s, Duration: 0.25s, Velocity: 90
#     Note Name: A4
#   Pitch: 67, Start: 4.25s, End: 4.5s, Duration: 0.25s, Velocity: 90
#     Note Name: G4
#   Pitch: 66, Start: 4.5s, End: 4.75s, Duration: 0.25s, Velocity: 90
#     Note Name: F#4
#   Pitch: 69, Start: 4.75s, End: 5.0s, Duration: 0.25s, Velocity: 90
#     Note Name: A4
#   Pitch: 74, Start: 5.0s, End: 5.25s, Duration: 0.25s, Velocity: 90
#     Note Name: D5
#   Pitch: 67, Start: 5.25s, End: 5.5s, Duration: 0.25s, Velocity: 90
#     Note Name: G4
#   Pitch: 71, Start: 5.5s, End: 5.75s, Duration: 0.25s, Velocity: 90
#     Note Name: B4
#   Pitch: 74, Start: 5.75s, End: 6.0s, Duration: 0.25s, Velocity: 90
#     Note Name: D5
#   Pitch: 67, Start: 6.0s, End: 6.25s, Duration: 0.25s, Velocity: 90
#     Note Name: G4
#   Pitch: 76, Start: 6.25s, End: 6.5s, Duration: 0.25s, Velocity: 90
#     Note Name: E5
#   Pitch: 74, Start: 6.5s, End: 6.75s, Duration: 0.25s, Velocity: 90
#     Note Name: D5
#   Pitch: 73, Start: 6.75s, End: 7.0s, Duration: 0.25s, Velocity: 90
#     Note Name: C#5
#   Pitch: 71, Start: 7.0s, End: 7.25s, Duration: 0.25s, Velocity: 90
#     Note Name: B4
#   Pitch: 73, Start: 7.25s, End: 7.5s, Duration: 0.25s, Velocity: 90
#     Note Name: C#5
#   Pitch: 74, Start: 7.5s, End: 7.75s, Duration: 0.25s, Velocity: 90
#     Note Name: D5
#   Pitch: 73, Start: 7.75s, End: 8.0s, Duration: 0.25s, Velocity: 90
#     Note Name: C#5
#   Pitch: 74, Start: 8.0s, End: 8.25s, Duration: 0.25s, Velocity: 90
#     Note Name: D5
#   Pitch: 66, Start: 8.25s, End: 8.5s, Duration: 0.25s, Velocity: 90
#     Note Name: F#4
#   Pitch: 69, Start: 8.5s, End: 8.75s, Duration: 0.25s, Velocity: 90
#     Note Name: A4
#   Pitch: 71, Start: 8.75s, End: 9.0s, Duration: 0.25s, Velocity: 90
#     Note Name: B4
#   Pitch: 74, Start: 9.0s, End: 9.25s, Duration: 0.25s, Velocity: 90
#     Note Name: D5
#   Pitch: 73, Start: 9.25s, End: 9.5s, Duration: 0.25s, Velocity: 90
#     Note Name: C#5
#   Pitch: 74, Start: 9.5s, End: 9.75s, Duration: 0.25s, Velocity: 90
#     Note Name: D5
#   Pitch: 71, Start: 9.75s, End: 10.25s, Duration: 0.5s, Velocity: 90
#     Note Name: B4
#   Pitch: 74, Start: 10.25s, End: 10.5s, Duration: 0.25s, Velocity: 90
#     Note Name: D5
#   Pitch: 71, Start: 10.5s, End: 10.75s, Duration: 0.25s, Velocity: 90
#     Note Name: B4
#   Pitch: 76, Start: 10.75s, End: 11.0s, Duration: 0.25s, Velocity: 90
#     Note Name: E5
#   Pitch: 74, Start: 11.0s, End: 11.25s, Duration: 0.25s, Velocity: 90
#     Note Name: D5
#   Pitch: 73, Start: 11.25s, End: 11.5s, Duration: 0.25s, Velocity: 90
#     Note Name: C#5
#   Pitch: 81, Start: 11.5s, End: 11.75s, Duration: 0.25s, Velocity: 90
#     Note Name: A5
#   Pitch: 79, Start: 11.75s, End: 12.0s, Duration: 0.25s, Velocity: 90
#     Note Name: G5
#   Pitch: 78, Start: 12.0s, End: 12.25s, Duration: 0.25s, Velocity: 90
#     Note Name: F#5
#   Pitch: 74, Start: 12.25s, End: 12.5s, Duration: 0.25s, Velocity: 90
#     Note Name: D5
#   Pitch: 73, Start: 12.5s, End: 12.75s, Duration: 0.25s, Velocity: 90
#     Note Name: C#5
#   Pitch: 74, Start: 12.75s, End: 13.25s, Duration: 0.5s, Velocity: 90
#     Note Name: D5
#   Pitch: 76, Start: 13.25s, End: 13.5s, Duration: 0.25s, Velocity: 90
#     Note Name: E5
#   Pitch: 74, Start: 13.5s, End: 13.75s, Duration: 0.25s, Velocity: 90
#     Note Name: D5
#   Pitch: 73, Start: 13.75s, End: 14.0s, Duration: 0.25s, Velocity: 90
#     Note Name: C#5
#   Pitch: 74, Start: 14.0s, End: 14.25s, Duration: 0.25s, Velocity: 90
#     Note Name: D5
#   Pitch: 66, Start: 14.25s, End: 14.5s, Duration: 0.25s, Velocity: 90
#     Note Name: F#4
#   Pitch: 69, Start: 14.5s, End: 14.75s, Duration: 0.25s, Velocity: 90
#     Note Name: A4
#   Pitch: 71, Start: 14.75s, End: 15.0s, Duration: 0.25s, Velocity: 90
#     Note Name: B4
#   Pitch: 74, Start: 15.0s, End: 15.25s, Duration: 0.25s, Velocity: 90
#     Note Name: D5
#   Pitch: 73, Start: 15.25s, End: 15.5s, Duration: 0.25s, Velocity: 90
#     Note Name: C#5
#   Pitch: 74, Start: 15.5s, End: 15.75s, Duration: 0.25s, Velocity: 90
#     Note Name: D5
#   Pitch: 71, Start: 15.75s, End: 16.0s, Duration: 0.25s, Velocity: 90
#     Note Name: B4
#   Pitch: 69, Start: 16.0s, End: 16.25s, Duration: 0.25s, Velocity: 90
#     Note Name: A4
#   Pitch: 67, Start: 16.25s, End: 16.5s, Duration: 0.25s, Velocity: 90
#     Note Name: G4
#   Pitch: 66, Start: 16.5s, End: 16.75s, Duration: 0.25s, Velocity: 90
#     Note Name: F#4
#   Pitch: 69, Start: 16.75s, End: 17.0s, Duration: 0.25s, Velocity: 90
#     Note Name: A4
#   Pitch: 74, Start: 17.0s, End: 17.25s, Duration: 0.25s, Velocity: 90
#     Note Name: D5
#   Pitch: 67, Start: 17.25s, End: 17.5s, Duration: 0.25s, Velocity: 90
#     Note Name: G4
#   Pitch: 71, Start: 17.5s, End: 17.75s, Duration: 0.25s, Velocity: 90
#     Note Name: B4
#   Pitch: 74, Start: 17.75s, End: 18.0s, Duration: 0.25s, Velocity: 90
#     Note Name: D5
#   Pitch: 67, Start: 18.0s, End: 18.25s, Duration: 0.25s, Velocity: 90
#     Note Name: G4
#   Pitch: 76, Start: 18.25s, End: 18.5s, Duration: 0.25s, Velocity: 90
#     Note Name: E5
#   Pitch: 74, Start: 18.5s, End: 18.75s, Duration: 0.25s, Velocity: 90
#     Note Name: D5
#   Pitch: 73, Start: 18.75s, End: 19.0s, Duration: 0.25s, Velocity: 90
#     Note Name: C#5
#   Pitch: 71, Start: 19.0s, End: 19.25s, Duration: 0.25s, Velocity: 90
#     Note Name: B4
#   Pitch: 73, Start: 19.25s, End: 19.5s, Duration: 0.25s, Velocity: 90
#     Note Name: C#5
#   Pitch: 74, Start: 19.5s, End: 19.75s, Duration: 0.25s, Velocity: 90
#     Note Name: D5
#   Pitch: 73, Start: 19.75s, End: 20.0s, Duration: 0.25s, Velocity: 90
#     Note Name: C#5
#   Pitch: 74, Start: 20.0s, End: 20.25s, Duration: 0.25s, Velocity: 90
#     Note Name: D5
#   Pitch: 66, Start: 20.25s, End: 20.5s, Duration: 0.25s, Velocity: 90
#     Note Name: F#4
#   Pitch: 69, Start: 20.5s, End: 20.75s, Duration: 0.25s, Velocity: 90
#     Note Name: A4
#   Pitch: 71, Start: 20.75s, End: 21.0s, Duration: 0.25s, Velocity: 90
#     Note Name: B4
#   Pitch: 74, Start: 21.0s, End: 21.25s, Duration: 0.25s, Velocity: 90
#     Note Name: D5
#   Pitch: 73, Start: 21.25s, End: 21.5s, Duration: 0.25s, Velocity: 90
#     Note Name: C#5
#   Pitch: 74, Start: 21.5s, End: 21.75s, Duration: 0.25s, Velocity: 90
#     Note Name: D5
#   Pitch: 71, Start: 21.75s, End: 22.25s, Duration: 0.5s, Velocity: 90
#     Note Name: B4
#   Pitch: 74, Start: 22.25s, End: 22.5s, Duration: 0.25s, Velocity: 90
#     Note Name: D5
#   Pitch: 71, Start: 22.5s, End: 22.75s, Duration: 0.25s, Velocity: 90
#     Note Name: B4
#   Pitch: 76, Start: 22.75s, End: 23.0s, Duration: 0.25s, Velocity: 90
#     Note Name: E5
#   Pitch: 74, Start: 23.0s, End: 23.25s, Duration: 0.25s, Velocity: 90
#     Note Name: D5
#   Pitch: 73, Start: 23.25s, End: 23.5s, Duration: 0.25s, Velocity: 90
#     Note Name: C#5
#   Pitch: 81, Start: 23.5s, End: 23.75s, Duration: 0.25s, Velocity: 90
#     Note Name: A5
#   Pitch: 79, Start: 23.75s, End: 24.0s, Duration: 0.25s, Velocity: 90
#     Note Name: G5
#   Pitch: 78, Start: 24.0s, End: 24.25s, Duration: 0.25s, Velocity: 90
#     Note Name: F#5
#   Pitch: 74, Start: 24.25s, End: 24.5s, Duration: 0.25s, Velocity: 90
#     Note Name: D5
#   Pitch: 73, Start: 24.5s, End: 24.75s, Duration: 0.25s, Velocity: 90
#     Note Name: C#5
#   Pitch: 74, Start: 24.75s, End: 25.25s, Duration: 0.5s, Velocity: 90
#     Note Name: D5
#   Pitch: 76, Start: 25.25s, End: 25.5s, Duration: 0.25s, Velocity: 90
#     Note Name: E5
#   Pitch: 78, Start: 25.5s, End: 25.75s, Duration: 0.25s, Velocity: 90
#     Note Name: F#5
#   Pitch: 74, Start: 25.75s, End: 26.0s, Duration: 0.25s, Velocity: 90
#     Note Name: D5
#   Pitch: 69, Start: 26.0s, End: 26.25s, Duration: 0.25s, Velocity: 90
#     Note Name: A4
#   Pitch: 79, Start: 26.25s, End: 27.0s, Duration: 0.75s, Velocity: 90
#     Note Name: G5
#   Pitch: 76, Start: 27.0s, End: 27.25s, Duration: 0.25s, Velocity: 90
#     Note Name: E5
#   Pitch: 72, Start: 27.25s, End: 27.5s, Duration: 0.25s, Velocity: 90
#     Note Name: C5
#   Pitch: 67, Start: 27.5s, End: 27.75s, Duration: 0.25s, Velocity: 90
#     Note Name: G4
#   Pitch: 77, Start: 27.75s, End: 28.5s, Duration: 0.75s, Velocity: 90
#     Note Name: F5
#   Pitch: 76, Start: 28.5s, End: 28.75s, Duration: 0.25s, Velocity: 90
#     Note Name: E5
#   Pitch: 72, Start: 28.75s, End: 29.0s, Duration: 0.25s, Velocity: 90
#     Note Name: C5
#   Pitch: 67, Start: 29.0s, End: 29.25s, Duration: 0.25s, Velocity: 90
#     Note Name: G4
#   Pitch: 67, Start: 29.25s, End: 29.5s, Duration: 0.25s, Velocity: 90
#     Note Name: G4
#   Pitch: 73, Start: 29.5s, End: 29.75s, Duration: 0.25s, Velocity: 90
#     Note Name: C#5
#   Pitch: 76, Start: 29.75s, End: 30.0s, Duration: 0.25s, Velocity: 90
#     Note Name: E5
#   Pitch: 72, Start: 30.0s, End: 30.25s, Duration: 0.25s, Velocity: 90
#     Note Name: C5
#   Pitch: 76, Start: 30.25s, End: 30.5s, Duration: 0.25s, Velocity: 90
#     Note Name: E5
#   Pitch: 79, Start: 30.5s, End: 30.75s, Duration: 0.25s, Velocity: 90
#     Note Name: G5
#   Pitch: 71, Start: 30.75s, End: 31.0s, Duration: 0.25s, Velocity: 90
#     Note Name: B4
#   Pitch: 74, Start: 31.0s, End: 31.25s, Duration: 0.25s, Velocity: 90
#     Note Name: D5
#   Pitch: 79, Start: 31.25s, End: 31.5s, Duration: 0.25s, Velocity: 90
#     Note Name: G5
#   Pitch: 78, Start: 31.5s, End: 31.75s, Duration: 0.25s, Velocity: 90
#     Note Name: F#5
#   Pitch: 74, Start: 31.75s, End: 32.0s, Duration: 0.25s, Velocity: 90
#     Note Name: D5
#   Pitch: 69, Start: 32.0s, End: 32.25s, Duration: 0.25s, Velocity: 90
#     Note Name: A4
#   Pitch: 79, Start: 32.25s, End: 33.0s, Duration: 0.75s, Velocity: 90
#     Note Name: G5
#   Pitch: 76, Start: 33.0s, End: 33.25s, Duration: 0.25s, Velocity: 90
#     Note Name: E5
#   Pitch: 73, Start: 33.25s, End: 33.5s, Duration: 0.25s, Velocity: 90
#     Note Name: C#5
#   Pitch: 69, Start: 33.5s, End: 33.75s, Duration: 0.25s, Velocity: 90
#     Note Name: A4
#   Pitch: 78, Start: 33.75s, End: 34.5s, Duration: 0.75s, Velocity: 90
#     Note Name: F#5
#   Pitch: 74, Start: 34.5s, End: 34.75s, Duration: 0.25s, Velocity: 90
#     Note Name: D5
#   Pitch: 76, Start: 34.75s, End: 35.0s, Duration: 0.25s, Velocity: 90
#     Note Name: E5
#   Pitch: 78, Start: 35.0s, End: 35.25s, Duration: 0.25s, Velocity: 90
#     Note Name: F#5
#   Pitch: 79, Start: 35.25s, End: 35.5s, Duration: 0.25s, Velocity: 90
#     Note Name: G5
#   Pitch: 76, Start: 35.5s, End: 35.75s, Duration: 0.25s, Velocity: 90
#     Note Name: E5
#   Pitch: 74, Start: 35.75s, End: 36.0s, Duration: 0.25s, Velocity: 90
#     Note Name: D5
#   Pitch: 73, Start: 36.0s, End: 36.25s, Duration: 0.25s, Velocity: 90
#     Note Name: C#5
#   Pitch: 71, Start: 36.25s, End: 36.5s, Duration: 0.25s, Velocity: 90
#     Note Name: B4
#   Pitch: 73, Start: 36.5s, End: 36.75s, Duration: 0.25s, Velocity: 90
#     Note Name: C#5
#   Pitch: 74, Start: 36.75s, End: 37.5s, Duration: 0.75s, Velocity: 90
#     Note Name: D5
#   Pitch: 78, Start: 37.5s, End: 37.75s, Duration: 0.25s, Velocity: 90
#     Note Name: F#5
#   Pitch: 74, Start: 37.75s, End: 38.0s, Duration: 0.25s, Velocity: 90
#     Note Name: D5
#   Pitch: 69, Start: 38.0s, End: 38.25s, Duration: 0.25s, Velocity: 90
#     Note Name: A4
#   Pitch: 79, Start: 38.25s, End: 39.0s, Duration: 0.75s, Velocity: 90
#     Note Name: G5
#   Pitch: 76, Start: 39.0s, End: 39.25s, Duration: 0.25s, Velocity: 90
#     Note Name: E5
#   Pitch: 72, Start: 39.25s, End: 39.5s, Duration: 0.25s, Velocity: 90
#     Note Name: C5
#   Pitch: 67, Start: 39.5s, End: 39.75s, Duration: 0.25s, Velocity: 90
#     Note Name: G4
#   Pitch: 77, Start: 39.75s, End: 40.5s, Duration: 0.75s, Velocity: 90
#     Note Name: F5
#   Pitch: 76, Start: 40.5s, End: 40.75s, Duration: 0.25s, Velocity: 90
#     Note Name: E5
#   Pitch: 72, Start: 40.75s, End: 41.0s, Duration: 0.25s, Velocity: 90
#     Note Name: C5
#   Pitch: 67, Start: 41.0s, End: 41.25s, Duration: 0.25s, Velocity: 90
#     Note Name: G4
#   Pitch: 67, Start: 41.25s, End: 41.5s, Duration: 0.25s, Velocity: 90
#     Note Name: G4
#   Pitch: 73, Start: 41.5s, End: 41.75s, Duration: 0.25s, Velocity: 90
#     Note Name: C#5
#   Pitch: 76, Start: 41.75s, End: 42.0s, Duration: 0.25s, Velocity: 90
#     Note Name: E5
#   Pitch: 72, Start: 42.0s, End: 42.25s, Duration: 0.25s, Velocity: 90
#     Note Name: C5
#   Pitch: 76, Start: 42.25s, End: 42.5s, Duration: 0.25s, Velocity: 90
#     Note Name: E5
#   Pitch: 79, Start: 42.5s, End: 42.75s, Duration: 0.25s, Velocity: 90
#     Note Name: G5
#   Pitch: 71, Start: 42.75s, End: 43.0s, Duration: 0.25s, Velocity: 90
#     Note Name: B4
#   Pitch: 74, Start: 43.0s, End: 43.25s, Duration: 0.25s, Velocity: 90
#     Note Name: D5
#   Pitch: 79, Start: 43.25s, End: 43.5s, Duration: 0.25s, Velocity: 90
#     Note Name: G5
#   Pitch: 78, Start: 43.5s, End: 43.75s, Duration: 0.25s, Velocity: 90
#     Note Name: F#5
#   Pitch: 74, Start: 43.75s, End: 44.0s, Duration: 0.25s, Velocity: 90
#     Note Name: D5
#   Pitch: 69, Start: 44.0s, End: 44.25s, Duration: 0.25s, Velocity: 90
#     Note Name: A4
#   Pitch: 79, Start: 44.25s, End: 45.0s, Duration: 0.75s, Velocity: 90
#     Note Name: G5
#   Pitch: 76, Start: 45.0s, End: 45.25s, Duration: 0.25s, Velocity: 90
#     Note Name: E5
#   Pitch: 73, Start: 45.25s, End: 45.5s, Duration: 0.25s, Velocity: 90
#     Note Name: C#5
#   Pitch: 69, Start: 45.5s, End: 45.75s, Duration: 0.25s, Velocity: 90
#     Note Name: A4
#   Pitch: 78, Start: 45.75s, End: 46.5s, Duration: 0.75s, Velocity: 90
#     Note Name: F#5
#   Pitch: 74, Start: 46.5s, End: 46.75s, Duration: 0.25s, Velocity: 90
#     Note Name: D5
#   Pitch: 76, Start: 46.75s, End: 47.0s, Duration: 0.25s, Velocity: 90
#     Note Name: E5
#   Pitch: 78, Start: 47.0s, End: 47.25s, Duration: 0.25s, Velocity: 90
#     Note Name: F#5
#   Pitch: 79, Start: 47.25s, End: 47.5s, Duration: 0.25s, Velocity: 90
#     Note Name: G5
#   Pitch: 76, Start: 47.5s, End: 47.75s, Duration: 0.25s, Velocity: 90
#     Note Name: E5
#   Pitch: 74, Start: 47.75s, End: 48.0s, Duration: 0.25s, Velocity: 90
#     Note Name: D5
#   Pitch: 73, Start: 48.0s, End: 48.25s, Duration: 0.25s, Velocity: 90
#     Note Name: C#5
#   Pitch: 71, Start: 48.25s, End: 48.5s, Duration: 0.25s, Velocity: 90
#     Note Name: B4
#   Pitch: 73, Start: 48.5s, End: 48.75s, Duration: 0.25s, Velocity: 90
#     Note Name: C#5
#   Pitch: 74, Start: 48.75s, End: 49.5s, Duration: 0.75s, Velocity: 90
#     Note Name: D5

# %%
print(midi.resolution)
# Out:
# 1024

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 tokenizer.config.time_division
#
# AttributeError: 'TokenizerConfig' object has no attribute 'time_division'
